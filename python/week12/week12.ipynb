# %%
import csv

file = open("./weather.csv", "r", encoding = "cp949")
data = csv.reader(file)

next(data)
initData = next(data)
highest = float(initData[4])
lowest = float(initData[3])
dailyTempRange = highest - lowest
highestDate = initData[0]
lowestDate = initData[0]
biggestRange = initData[0]

for row in data:
    tempRange = float(row[4])-float(row[3])
    #print(tempRange)
    if highest < float(row[4]):
        highest = float(row[4])
        highestDate = row[0]
    if lowest > float(row[3]):
        lowest = float(row[3])
        lowestDate = row[0]
    if dailyTempRange < tempRange:
        dailyTempRange = tempRange
        biggestRange = row[0]

file.close()

print("일교차가 가장 큰 날")
print(biggestRange)
print("최저기온이 가장 낮은 날")
print(lowestDate)
print("최고기온이 가장 높은 날")
print(highestDate)
# Out:
# 일교차가 가장 큰 날
# 2021-04-21
# 최저기온이 가장 낮은 날
# 2021-01-08
# 최고기온이 가장 높은 날
# 2021-07-24

# %%
import csv

file = open("./metro.csv", "r", encoding="UTF8")
data = csv.reader(file)
next(data)
user = {}
userDic = {}
line = {}
lineNum = ""
tmp = 0

for row in data:
    if (row[1], row[2]) in user:
        user[(row[1], row[2])] += (int(row[3]) + int(row[4]))
    else:
        user[(row[1], row[2])] = int(row[3]) + int(row[4])

user = sorted(user.items())

for i in user:
    userDic[i[0]] = i[1]

while True:
    if len(userDic) == 0:
        break

    for key, value in userDic.items():
        if tmp == 0:
            tmp = 1
            lineNum = key[0]
        if lineNum == key[0]:
            line[key[1]] = value
        else:
            continue
    tmp = 0

    for key in line.keys():
        del(userDic[(lineNum,key)])

    result = sorted(line.items(), key=(lambda x:x[1]), reverse = True)
    print("==========="+ lineNum +"===========")
    print("이용객이 가장 많은 역 순위")
    print("1. {0}({1}명)".format(result[0][0], result[0][1]))
    print("2. {0}({1}명)".format(result[1][0], result[1][1]))
    print("3. {0}({1}명)".format(result[2][0], result[2][1]))
    print("이용객이 가장 적은 역 순위")
    print("1. {0}({1}명)".format(result[-1][0], result[-1][1]))
    print("2. {0}({1}명)".format(result[-2][0], result[-2][1]))
    print("3. {0}({1}명)".format(result[-3][0], result[-3][1]))
    print()

    lineNum = ""
    line.clear()
# Out:
# ===========1호선===========
# 이용객이 가장 많은 역 순위
# 1. 서울역(2331792명)
# 2. 종각(1714643명)
# 3. 종로3가(1348194명)
# 이용객이 가장 적은 역 순위
# 1. 동묘앞(566788명)
# 2. 동대문(632304명)
# 3. 신설동(736913명)
#
# ===========2호선===========
# 이용객이 가장 많은 역 순위
# 1. 잠실(송파구청)(4324604명)
# 2. 강남(4313964명)
# 3. 신림(3411272명)
# 이용객이 가장 적은 역 순위
# 1. 도림천(77493명)
# 2. 신답(92373명)
# 3. 용두(동대문구청)(127271명)
#
# ===========3호선===========
# 이용객이 가장 많은 역 순위
# 1. 고속터미널(2440654명)
# 2. 양재(서초구청)(2028915명)
# 3. 연신내(1952915명)
# 이용객이 가장 적은 역 순위
# 1. 충무로(38명)
# 2. 학여울(125866명)
# 3. 무악재(213385명)
#
# ===========4호선===========
# 이용객이 가장 많은 역 순위
# 1. 수유(강북구청)(1856708명)
# 2. 혜화(1821858명)
# 3. 쌍문(1519040명)
# 이용객이 가장 적은 역 순위
# 1. 남태령(63516명)
# 2. 동작(현충원)(112172명)
# 3. 삼각지(290564명)
#
# ===========5호선===========
# 이용객이 가장 많은 역 순위
# 1. 광화문(세종문화회관)(1531794명)
# 2. 까치산(1525926명)
# 3. 여의도(1501672명)
# 이용객이 가장 적은 역 순위
# 1. 동대문역사문화공원(DDP)(146797명)
# 2. 오금(198034명)
# 3. 청구(202623명)
#
# ===========6호선===========
# 이용객이 가장 많은 역 순위
# 1. 응암(959058명)
# 2. 공덕(924083명)
# 3. 망원(817057명)
# 이용객이 가장 적은 역 순위
# 1. 신내(6명)
# 2. 연신내(22명)
# 3. 버티고개(113582명)
#
# ===========7호선===========
# 이용객이 가장 많은 역 순위
# 1. 가산디지털단지(2139876명)
# 2. 학동(1214306명)
# 3. 광명사거리(1194578명)
# 이용객이 가장 적은 역 순위
# 1. 신중동(1명)
# 2. 부천종합운동장(1명)
# 3. 굴포천(1명)
#
# ===========8호선===========
# 이용객이 가장 많은 역 순위
# 1. 문정(1093364명)
# 2. 암사(945049명)
# 3. 잠실(송파구청)(926208명)
# 이용객이 가장 적은 역 순위
# 1. 신흥(240760명)
# 2. 모란(252256명)
# 3. 남위례(268170명)
#
# ===========9호선===========
# 이용객이 가장 많은 역 순위
# 1. 신논현(1706017명)
# 2. 노량진(1438891명)
# 3. 여의도(1418879명)
# 이용객이 가장 적은 역 순위
# 1. 구반포(73485명)
# 2. 개화(115479명)
# 3. 동작(현충원)(125524명)
#
# ===========9호선2~3단계===========
# 이용객이 가장 많은 역 순위
# 1. 봉은사(866793명)
# 2. 언주(533627명)
# 3. 선정릉(509471명)
# 이용객이 가장 적은 역 순위
# 1. 둔촌오륜(60139명)
# 2. 한성백제(135285명)
# 3. 종합운동장(238687명)
#
# ===========경강선===========
# 이용객이 가장 많은 역 순위
# 1. 경기광주(408568명)
# 2. 판교(247429명)
# 3. 초월(168344명)
# 이용객이 가장 적은 역 순위
# 1. 세종대왕릉(20295명)
# 2. 이매(57849명)
# 3. 신둔도예촌(87690명)
#
# ===========경부선===========
# 이용객이 가장 많은 역 순위
# 1. 수원(2231560명)
# 2. 영등포(2224000명)
# 3. 용산(1950999명)
# 이용객이 가장 적은 역 순위
# 1. 직산(48909명)
# 2. 서동탄(73767명)
# 3. 진위(90226명)
#
# ===========경원선===========
# 이용객이 가장 많은 역 순위
# 1. 의정부(1096932명)
# 2. 청량리(서울시립대입구)(916325명)
# 3. 왕십리(성동구청)(844739명)
# 이용객이 가장 적은 역 순위
# 1. 창동(9명)
# 2. 옥수(2607명)
# 3. 보산(100012명)
#
# ===========경의선===========
# 이용객이 가장 많은 역 순위
# 1. 일산(527526명)
# 2. 행신(437155명)
# 3. 야당(432277명)
# 이용객이 가장 적은 역 순위
# 1. 김포공항(2명)
# 2. 검암(2명)
# 3. 계양(8명)
#
# ===========경인선===========
# 이용객이 가장 많은 역 순위
# 1. 부천(1854984명)
# 2. 부평(1745542명)
# 3. 역곡(1529363명)
# 이용객이 가장 적은 역 순위
# 1. 도원(178834명)
# 2. 인천(225773명)
# 3. 도화(225791명)
#
# ===========경춘선===========
# 이용객이 가장 많은 역 순위
# 1. 평내호평(349872명)
# 2. 마석(236122명)
# 3. 퇴계원(189281명)
# 이용객이 가장 적은 역 순위
# 1. 백양리(6906명)
# 2. 굴봉산(12469명)
# 3. 상천(23488명)
#
# ===========공항철도 1호선===========
# 이용객이 가장 많은 역 순위
# 1. 디지털미디어시티(655183명)
# 2. 홍대입구(592401명)
# 3. 계양(555208명)
# 이용객이 가장 적은 역 순위
# 1. 공항화물청사(122833명)
# 2. 공덕(143140명)
# 3. 인천공항2터미널(144685명)
#
# ===========과천선===========
# 이용객이 가장 많은 역 순위
# 1. 범계(1433694명)
# 2. 인덕원(1330432명)
# 3. 평촌(889935명)
# 이용객이 가장 적은 역 순위
# 1. 경마공원(331351명)
# 2. 과천(337470명)
# 3. 대공원(389558명)
#
# ===========분당선===========
# 이용객이 가장 많은 역 순위
# 1. 야탑(1424216명)
# 2. 서현(1319161명)
# 3. 모란(1207397명)
# 이용객이 가장 적은 역 순위
# 1. 복정(13명)
# 2. 구룡(121727명)
# 3. 보정(129780명)
#
# ===========수인선===========
# 이용객이 가장 많은 역 순위
# 1. 인하대(374455명)
# 2. 소래포구(350953명)
# 3. 인천논현(318318명)
# 이용객이 가장 적은 역 순위
# 1. 달월(5052명)
# 2. 야목(19625명)
# 3. 어천(45500명)
#
# ===========안산선===========
# 이용객이 가장 많은 역 순위
# 1. 중앙(1062429명)
# 2. 산본(916214명)
# 3. 상록수(913765명)
# 이용객이 가장 적은 역 순위
# 1. 신길온천(98533명)
# 2. 반월(240189명)
# 3. 수리산(249459명)
#
# ===========우이신설선===========
# 이용객이 가장 많은 역 순위
# 1. 북한산보국문(328363명)
# 2. 솔샘(301277명)
# 3. 정릉(249475명)
# 이용객이 가장 적은 역 순위
# 1. 보문(84182명)
# 2. 삼양(113276명)
# 3. 신설동(115536명)
#
# ===========일산선===========
# 이용객이 가장 많은 역 순위
# 1. 삼송(1063564명)
# 2. 화정(936907명)
# 3. 대화(613897명)
# 이용객이 가장 적은 역 순위
# 1. 지축(5명)
# 2. 대곡(108864명)
# 3. 마두(404818명)
#
# ===========장항선===========
# 이용객이 가장 많은 역 순위
# 1. 온양온천(242044명)
# 2. 아산(214983명)
# 3. 쌍용(나사렛대)(147927명)
# 이용객이 가장 적은 역 순위
# 1. 탕정(43568명)
# 2. 봉명(66397명)
# 3. 배방(68071명)
#
# ===========중앙선===========
# 이용객이 가장 많은 역 순위
# 1. 회기(1394264명)
# 2. 구리(748593명)
# 3. 도농(553781명)
# 이용객이 가장 적은 역 순위
# 1. 지평(4754명)
# 2. 신원(16191명)
# 3. 오빈(19638명)
